# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
HL= pd.read_csv('Housingtrain.csv')

# %%
HL
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
# ...

# %%
HL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    954 non-null    float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   Alley          77 non-null     object
#  7   LotShape       1168 non-null   object
#  8   LandContour    1168 non-null   object
#  9   Utilities      1168 non-null   object
#  10  LotConfig      1168 non-null   object
#  11  LandSlope      1168 non-null   object
#  12  Neighborhood   1168 non-null   object
#  13  Condition1     1168 non-null   object
#  14  Condition2     1168 non-null   object
#  15  BldgType       1168 non-null   object
#  16  HouseStyle     1168 non-null   object
# ...

# %%
HL.isnull().values.any()
# Out:
# True

# %%
HL.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      214
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
HL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    954 non-null    float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   Alley          77 non-null     object
#  7   LotShape       1168 non-null   object
#  8   LandContour    1168 non-null   object
#  9   Utilities      1168 non-null   object
#  10  LotConfig      1168 non-null   object
#  11  LandSlope      1168 non-null   object
#  12  Neighborhood   1168 non-null   object
#  13  Condition1     1168 non-null   object
#  14  Condition2     1168 non-null   object
#  15  BldgType       1168 non-null   object
#  16  HouseStyle     1168 non-null   object
# ...

# %%
HL = HL.sort_values(by=["Id"], ascending=True)

# %%
HL
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 427      1          60       RL         65.0     8450   Pave   NaN      Reg
# 146      2          20       RL         80.0     9600   Pave   NaN      Reg
# 102      3          60       RL         68.0    11250   Pave   NaN      IR1
# 143      4          70       RL         60.0     9550   Pave   NaN      IR1
# 280      5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 584   1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1092  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1144  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 22    1459          20       RL         68.0     9717   Pave   NaN      Reg
# 309   1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
HL.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 427   1          60       RL         65.0     8450   Pave   NaN      Reg
# 146   2          20       RL         80.0     9600   Pave   NaN      Reg
# 102   3          60       RL         68.0    11250   Pave   NaN      IR1
# 143   4          70       RL         60.0     9550   Pave   NaN      IR1
# 280   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 427         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 146         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 102         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 143         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 280         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
HL.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
sns.heatmap(HL.isnull())
plt.show()

# %%
HL.drop('Id', axis=1,inplace=True)

# %%
HL
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 427           60       RL         65.0     8450   Pave   NaN      Reg
# 146           20       RL         80.0     9600   Pave   NaN      Reg
# 102           60       RL         68.0    11250   Pave   NaN      IR1
# 143           70       RL         60.0     9550   Pave   NaN      IR1
# 280           60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 584           20       RL         90.0    17217   Pave   NaN      Reg
# 1092          20       RL         85.0    13175   Pave   NaN      Reg
# 1144          70       RL         66.0     9042   Pave   NaN      Reg
# 22            20       RL         68.0     9717   Pave   NaN      Reg
# 309           20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
HL = HL.sort_values(by=["MSSubClass"], ascending=True)

# %%
HL
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 309          20       RL         75.0     9937   Pave   NaN      Reg
# 60           20       RL         60.0     7200   Pave   NaN      Reg
# 68           20       RL          NaN    32668   Pave   NaN      IR1
# 41           20       RL         70.0    13300   Pave   NaN      Reg
# 365          20       FV         62.0     7500   Pave  Pave      Reg
# ..          ...      ...          ...      ...    ...   ...      ...
# 884         190       RL         60.0    10800   Pave  Grvl      Reg
# 210         190       RM         69.0     9142   Pave  Grvl      Reg
# 705         190       RL         75.0    10382   Pave   NaN      Reg
# 966         190       RL         68.0    10880   Pave   NaN      Reg
# 581         190       RL         60.0     9873   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# ...

# %%
HL_float=HL[['LotFrontage', 'MasVnrArea','GarageYrBlt']].copy()
HL_float
# Out:
#      LotFrontage  MasVnrArea  GarageYrBlt
# 309         75.0         0.0       1965.0
# 60          60.0         0.0       1967.0
# 68           NaN         NaN       1975.0
# 41          70.0         0.0       1956.0
# 365         62.0         0.0       2005.0
# ..           ...         ...          ...
# 884         60.0         0.0          NaN
# 210         69.0         0.0       1910.0
# 705         75.0       105.0       1958.0
# 966         68.0         0.0       1950.0
# 581         60.0       160.0       1970.0
#
# [1168 rows x 3 columns]

# %%
HL_float.isnull().sum()
# Out:
# LotFrontage    214
# MasVnrArea       7
# GarageYrBlt     64
# dtype: int64

# %%
HL_float['MasVnrArea'] = HL_float['MasVnrArea'].replace(np.nan, 0)
HL_float.isnull().sum()
# Out:
# LotFrontage    214
# MasVnrArea       0
# GarageYrBlt     64
# dtype: int64

# %%
HL_float['GarageYrBlt'] = HL_float['GarageYrBlt'].fillna(0)

# %%
HL_float['LotFrontage']= HL_float['LotFrontage'].replace(np.NaN,0)

# %%
HL_float.head()
# Out:
#      LotFrontage  MasVnrArea  GarageYrBlt
# 309         75.0         0.0       1965.0
# 60          60.0         0.0       1967.0
# 68           0.0         0.0       1975.0
# 41          70.0         0.0       1956.0
# 365         62.0         0.0       2005.0

# %%
HL_num=HL[['MSSubClass',  'LotArea' , 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr','TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']].copy()
HL_num
# Out:
#      MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 309          20     9937            5            6       1965          1965
# 60           20     7200            5            7       1955          2007
# 68           20    32668            6            3       1957          1975
# 41           20    13300            5            7       1956          2000
# 365          20     7500            7            5       2005          2005
# ..          ...      ...          ...          ...        ...           ...
# 884         190    10800            4            7       1900          2000
# 210         190     9142            6            8       1910          1950
# 705         190    10382            6            5       1958          1958
# 966         190    10880            5            5       1950          1950
# 581         190     9873            4            5       1970          1970
#
# ...

# %%
HL_cat=HL[['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'Functional',
       'FireplaceQu', 'GarageType', 'KitchenQual', 'GarageFinish',
       'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence',
       'MiscFeature', 'SaleType', 'SaleCondition']].copy()

# %%
HL_num.isnull().sum()
# Out:
# MSSubClass       0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SalePrice        0
# dtype: int64

# %%
HL_cat.isnull().sum()
# Out:
# MSZoning            0
# Street              0
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          7
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           30
# BsmtCond           30
# BsmtExposure       31
# BsmtFinType1       30
# BsmtFinType2       31
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          0
# Functional          0
# FireplaceQu       551
# GarageType         64
# KitchenQual         0
# GarageFinish       64
# GarageQual         64
# GarageCond         64
# PavedDrive          0
# PoolQC           1161
# Fence             931
# MiscFeature      1124
# SaleType            0
# ...

# %%
HL_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1168 entries, 309 to 581
# Data columns (total 42 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       1168 non-null   object
#  1   Street         1168 non-null   object
#  2   LotShape       1168 non-null   object
#  3   LandContour    1168 non-null   object
#  4   Utilities      1168 non-null   object
#  5   LotConfig      1168 non-null   object
#  6   LandSlope      1168 non-null   object
#  7   Neighborhood   1168 non-null   object
#  8   Condition1     1168 non-null   object
#  9   Condition2     1168 non-null   object
#  10  BldgType       1168 non-null   object
#  11  HouseStyle     1168 non-null   object
#  12  RoofStyle      1168 non-null   object
#  13  RoofMatl       1168 non-null   object
#  14  Exterior1st    1168 non-null   object
#  15  Exterior2nd    1168 non-null   object
#  16  MasVnrType     1161 non-null   object
# ...

# %%
HL_cat['MasVnrType'] = HL_cat['MasVnrType'].fillna(0)

# %%
HL_cat.head()
# Out:
#     MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 309       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 60        RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 68        RL   Pave      IR1         Lvl    AllPub   CulDSac       Gtl
# 41        RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 365       FV   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#     Neighborhood Condition1 Condition2  ... KitchenQual GarageFinish  \
# 309      Edwards       Norm       Norm  ...          TA          Fin
# 60         NAmes       Norm       Norm  ...          TA          Unf
# 68       Crawfor       Norm       Norm  ...          TA          RFn
# 41         NAmes       Norm       Norm  ...          TA          Unf
# 365      Somerst       Norm       Norm  ...          Gd          Unf
#
#     GarageQual GarageCond PavedDrive PoolQC Fence MiscFeature SaleType  \
# ...

# %%
HL_cat.columns
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'Functional',
#        'FireplaceQu', 'GarageType', 'KitchenQual', 'GarageFinish',
#        'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence',
#        'MiscFeature', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
HL_cat['BsmtCond'] = HL_cat['BsmtCond'].replace(np.NaN,'NA')
HL_cat['BsmtExposure'] = HL_cat['BsmtExposure'].replace(np.NaN,'NA')
HL_cat['BsmtFinType1'] = HL_cat['BsmtFinType1'].replace(np.NaN,'NA')
HL_cat['BsmtFinType2'] = HL_cat['BsmtFinType2'].replace(np.NaN,'NA')

# %%
HL_cat.head()
# Out:
#     MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 309       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 60        RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 68        RL   Pave      IR1         Lvl    AllPub   CulDSac       Gtl
# 41        RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 365       FV   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#     Neighborhood Condition1 Condition2  ... KitchenQual GarageFinish  \
# 309      Edwards       Norm       Norm  ...          TA          Fin
# 60         NAmes       Norm       Norm  ...          TA          Unf
# 68       Crawfor       Norm       Norm  ...          TA          RFn
# 41         NAmes       Norm       Norm  ...          TA          Unf
# 365      Somerst       Norm       Norm  ...          Gd          Unf
#
#     GarageQual GarageCond PavedDrive PoolQC Fence MiscFeature SaleType  \
# ...

# %%
HL_cat['BsmtQual'] = HL_cat['BsmtQual'].replace(np.NaN,'NA')

# %%
HL_cat['FireplaceQu'] = HL_cat['FireplaceQu'].replace(np.NaN,'NA')

# %%
HL_cat['FireplaceQu']
# Out:
# 309    NA
# 60     Po
# 68     TA
# 41     NA
# 365    TA
#        ..
# 884    NA
# 210    NA
# 705    NA
# 966    NA
# 581    NA
# Name: FireplaceQu, Length: 1168, dtype: object

# %%
HL_cat['GarageType']= HL_cat['GarageType'].replace(np.NaN,'NA')
HL_cat['GarageFinish']= HL_cat['GarageFinish'].replace(np.NaN,'NA')
HL_cat['GarageQual']= HL_cat['GarageQual'].replace(np.NaN,'NA')
HL_cat['GarageCond']= HL_cat['GarageCond'].replace(np.NaN,'NA')
HL_cat['PoolQC']= HL_cat['PoolQC'].replace(np.NaN,'NA')
HL_cat['Fence']= HL_cat['Fence'].replace(np.NaN,'NA')
HL_cat['MiscFeature']= HL_cat['MiscFeature'].replace(np.NaN,'NA')

# %%
HL_cat.head()
# Out:
#     MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 309       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 60        RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 68        RL   Pave      IR1         Lvl    AllPub   CulDSac       Gtl
# 41        RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 365       FV   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#     Neighborhood Condition1 Condition2  ... KitchenQual GarageFinish  \
# 309      Edwards       Norm       Norm  ...          TA          Fin
# 60         NAmes       Norm       Norm  ...          TA          Unf
# 68       Crawfor       Norm       Norm  ...          TA          RFn
# 41         NAmes       Norm       Norm  ...          TA          Unf
# 365      Somerst       Norm       Norm  ...          Gd          Unf
#
#     GarageQual GarageCond PavedDrive PoolQC Fence MiscFeature SaleType  \
# ...

# %%
HL_final = pd.concat([HL_num,HL_float,HL_cat], axis=1)
HL_final.head()
# Out:
#      MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 309          20     9937            5            6       1965          1965
# 60           20     7200            5            7       1955          2007
# 68           20    32668            6            3       1957          1975
# 41           20    13300            5            7       1956          2000
# 365          20     7500            7            5       2005          2005
#
#      BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  KitchenQual  \
# 309         830         290        136         1256  ...           TA
# 60            0           0          0            0  ...           TA
# 68         1219           0        816         2035  ...           TA
# 41          377           0        551          928  ...           TA
# 365           0           0       1257         1257  ...           Gd
#
#      GarageFinish  GarageQual  GarageCond  PavedDrive  PoolQC  Fence  \
# ...

# %%
HL_final.isnull().sum()
# Out:
# MSSubClass       0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
#                 ..
# PoolQC           0
# Fence            0
# MiscFeature      0
# SaleType         0
# SaleCondition    0
# Length: 79, dtype: int64

# %%
HL_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1168 entries, 309 to 581
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1168 non-null   int64
#  1   LotArea        1168 non-null   int64
#  2   OverallQual    1168 non-null   int64
#  3   OverallCond    1168 non-null   int64
#  4   YearBuilt      1168 non-null   int64
#  5   YearRemodAdd   1168 non-null   int64
#  6   BsmtFinSF1     1168 non-null   int64
#  7   BsmtFinSF2     1168 non-null   int64
#  8   BsmtUnfSF      1168 non-null   int64
#  9   TotalBsmtSF    1168 non-null   int64
#  10  1stFlrSF       1168 non-null   int64
#  11  2ndFlrSF       1168 non-null   int64
#  12  LowQualFinSF   1168 non-null   int64
#  13  GrLivArea      1168 non-null   int64
#  14  BsmtFullBath   1168 non-null   int64
#  15  BsmtHalfBath   1168 non-null   int64
#  16  FullBath       1168 non-null   int64
#  17  HalfBath       1168 non-null   int64
# ...

# %%
sns.heatmap(HL_final.isnull())
plt.show()
